# %% [markdown]
# #Python Project EDA & Data Visualization-AirBnB Listing 2025(new)

# %% [markdown]
# ## Steps ##
# 1) importing all dependencies (lib)
# 2) loading datasets
# 3) initial exploration
# 4) Data cleaning
# 5) Data Analysis

# %%
# importing all dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# loading the dataset

# %%
file_path = r"C:\Users\hp\Downloads\datasets.csv"  # Ensure the file is named correctly
data = pd.read_csv(file_path, encoding_errors='ignore')

# Check the first few rows of the dataset
print(data.head())
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %% [markdown]
# Task 3  data exploration

# %%
data.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
# to view last few rows
data.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
# ...

# %%
data.shape  # to view how many rows and column
# Out:
# (20770, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
data.describe()  # to view the statstical view
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %% [markdown]
# Data cleaning

# %%
# missing values in the dataset
data.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      7
# latitude                           7
# longitude                          7
# room_type                          7
# price                             34
# minimum_nights                     7
# number_of_reviews                  7
# last_review                        7
# reviews_per_month                  7
# calculated_host_listings_count     7
# availability_365                   7
# number_of_reviews_ltm              7
# license                            0
# rating                             0
# bedrooms                           0
# beds                               0
# baths                              0
# dtype: int64

# %%
# droping all missing value rows
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
data.shape
# Out:
# (20736, 22)

# %%
#dealing with duplicated rows
data.duplicated().sum()
# Out:
# 12

# %%
#deleting all duplicated record 
data.drop_duplicates(inplace=True)

# %%
# to view duplicated vaues
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes  # to view the datatpyes of each column
# Out:
# id                                float64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
#type casting --changing the datatype 
data['id']=data['id'].astype(object)  # update id datatype to object

# %%
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# EDA
# # task 5 Data Anlysis

# %% [markdown]
# univirate Analysis

# %%
# identifying the outliers in the price
df = data[data['price'] < 1500]
sns.boxplot(data=df,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
#price analysis
data['price']
# Out:
# 0         55.0
# 1        144.0
# 2        187.0
# 3        120.0
# 4         85.0
#          ...
# 20765     45.0
# 20766    105.0
# 20767    299.0
# 20768    115.0
# 20769    102.0
# Name: price, Length: 20724, dtype: float64

# %%
plt.figure(figsize =(10,5))
sns.histplot(data=df,x='price')
plt.title("Price Distribution")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
df["availability_365"]
# Out:
# 0          0.0
# 1        364.0
# 2        343.0
# 3        363.0
# 4        335.0
#          ...
# 20765    157.0
# 20766      0.0
# 20767      0.0
# 20768    363.0
# 20769      0.0
# Name: availability_365, Length: 20636, dtype: float64

# %%
sns.histplot(data=data,x="availability_365",color="Red")
plt.title("Room Availability 365")
plt.xlabel("Days")
plt.ylabel("No of Rooms Available")
plt.show()

# %%
df.groupby(by="neighbourhood_group")["price"].mean()
# Out:
# neighbourhood_group
# Bronx            107.990506
# Brooklyn         155.138317
# Manhattan        204.146014
# Queens           121.681939
# Staten Island    118.780069
# Name: price, dtype: float64

# %%
# Feature Engineering
df['price_per_bed']df['price']/df['beds']

# %%
df.head()
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  last_review  \
# ...

# %% [markdown]
# Bi Variable Analysis

# %%
# One Variable Dependency in another variable

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
# price Dependencies on neighbourhood
sns.barplot(data=df,x="neighbourhood_group",y='price',hue="room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
sns.scatterplot(data=df,x="price",y="number_of_reviews",hue="room_type")
plt.title("Locality and reviews")
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
sns.pairplot(data=df,vars=["price","minimum_nights","number_of_reviews","availability_365"],hue="room_type")

# %%
#geographical distribution
plt.figure(figsize=(10,7))
sns.scatterplot(data=df,y="latitude",x="longitude",hue="room_type")     
plt.title("Geographical Distribution of AirBnB Listing")
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# # heatmap chart --Coorelation of one variable with others for numerical columms

# %%
corr=df[["latitude","longitude","price","number_of_reviews","reviews_per_month","availability_365","beds"]].corr()
corr
# Out:
#                    latitude  longitude     price  number_of_reviews  \
# latitude           1.000000   0.047369  0.012686          -0.047953
# longitude          0.047369   1.000000 -0.193728           0.004820
# price              0.012686  -0.193728  1.000000          -0.043533
# number_of_reviews -0.047953   0.004820 -0.043533           1.000000
# reviews_per_month -0.041673   0.041720 -0.012775           0.631005
# availability_365  -0.005941   0.063523  0.048036          -0.049656
# beds              -0.071753   0.041832  0.415278           0.040071
#
#                    reviews_per_month  availability_365      beds
# latitude                   -0.041673         -0.005941 -0.071753
# longitude                   0.041720          0.063523  0.041832
# price                      -0.012775          0.048036  0.415278
# number_of_reviews           0.631005         -0.049656  0.040071
# reviews_per_month           1.000000         -0.040116  0.053496
# ...

# %%
plt.figure(figsize=(8,5))
sns.heatmap(data=corr,annot=True)
# Out:
# <Axes: >
